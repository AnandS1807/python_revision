# %%
#indexing
question  = "what kind of games do you like ?"
document = "i like to play RDR2."

# %%
#counbting the number of tokens
import tiktoken

def num_of_token(string : str, encoding_name: str)->int: 
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
num_of_token(question, "cl100k_base")
# Out:
# 8

# %%
from langchain_openai import OpenAIEmbeddings

emb = OpenAIEmbeddings()

text = "My favorite pet is a cat"
vector = emb.embed_query(text)

print(len(vector))  # ~1536 numbers
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain_openai import OpenAIEmbeddings
#       3 emb = OpenAIEmbeddings()
#       5 text = "My favorite pet is a cat"
#
# ModuleNotFoundError: No module named 'langchain_openai'
